# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the Excel file into a DataFrame
df = pd.read_excel("./Industry-data-raw/ALPINHWS.xls")
df.head(20)
# Out:
#                                   2025-08-15 16:24:57 Unnamed: 1 Unnamed: 2  \
# 0                   Employment Development Department        NaN        NaN
# 1                   Labor Market Information Division        NaN        NaN
# 2                                      (916) 262-2162        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                                 NaN        NaN        NaN
# 5   See notes at bottom of page for column definit...        NaN        NaN
# 6                                           SORTORDER     BMYEAR       AREA
# 7                                                   1       2024          3
# 8                                                   2       2024          3
# 9                                                   3       2024          3
# 10                                                  4       2024          3
# ...

# %%
file_name = df.iloc[0, 6]

file_name = df.iloc[0, 6]

if "county" not in file_name.lower():   # check case-insensitive
    file_name = df.iloc[1, 6]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 file_name = df.iloc[0, 6]
# ----> 3 if not file_name.str.contains('County'):
#       4     file_name = df.iloc[1,6]
#
# AttributeError: 'str' object has no attribute 'str'
